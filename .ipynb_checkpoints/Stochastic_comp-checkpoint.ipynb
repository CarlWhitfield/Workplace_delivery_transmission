# %% [markdown]
# Stochastic (Gillespie) version of SEIR model

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append(".")
import simple_SEIR_package as detsim
import Gillespie_package_SEIR as stochsim

# %% [markdown]
# Case 1: No external FOI, just study system in isolation
# Approximate final distribution of Rd, Rl, Ro for single infection in L

# %%
ip = 0
NP = 5000
Nsim = 1000
alphaT = 0.001
alphaC = 0.001
sigma = 1/5
gamma = 1/3
FOI = 0.0
n=np.array([50,15,10])
s=np.array([50,14,10])
e = n-s
i = np.zeros(3,dtype=np.int)
ntot = np.sum(n)

# %%
beta = 0.3
td = 0.2
S,E,I,R = detsim.SIRsim(beta,td,sigma,gamma,FOI,n[0]/np.sum(n),n[1]/np.sum(n),n[2]/np.sum(n),\
                                alphaT,alphaC,1/n[1],0.1,1000)
t,sim = stochsim.run_gillespie(n,s,e,i,NP,ip,beta,td,alphaT,alphaC,sigma,gamma,FOI,tend=100)

# %%
plt.plot(np.arange(1001)*0.1,S[0,:]*ntot)
plt.plot(t,sim[0,:])

# %%
full_states = np.zeros((5,5,1000),dtype=np.object)
det_states = np.zeros((5,5),dtype=np.object)
times = np.zeros((5,5,1000),dtype=np.object)
for j in np.arange(5):
    td = 0.05*(j+1)
    for k in np.arange(5):
        beta = (k+1)/5
        S,E,I,R = detsim.SIRsim(beta,td,sigma,gamma,FOI,n[0]/np.sum(n),n[1]/np.sum(n),n[2]/np.sum(n),\
                                alphaT,alphaC,1/n[1],0.1,1000)
        det_states[k,j] = [S,E,I,R]
        for p in np.arange(Nsim):
            t,sim = stochsim.run_gillespie(n,s,e,i,NP,ip,beta,td,alphaT,alphaC,sigma,gamma,FOI,5000)
            full_states[k,j,p] = sim
            times[k,j,p] = t

# %%
n=np.array([50,15,10])
s=np.array([50,14,10])
e = n-s
i = np.zeros(3,dtype=np.int)
k = 4
j = 4
for p in np.arange(1000):
    plt.plot(times[k,j,p],full_states[k,j,p][0,:],c='C0',alpha=0.1)
    plt.plot(times[k,j,p],full_states[k,j,p][1,:],c='C1',alpha=0.1)
    plt.plot(times[k,j,p],full_states[k,j,p][2,:],c='C2',alpha=0.1)
plt.plot(np.arange(1001)*0.1,det_states[k,j][0][0,:]*ntot,c='k')
plt.plot(np.arange(1001)*0.1,det_states[k,j][0][1,:]*ntot,c='k')
plt.plot(np.arange(1001)*0.1,det_states[k,j][0][2,:]*ntot,c='k')
