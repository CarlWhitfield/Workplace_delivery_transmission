# %%
import numpy as np
import matplotlib.pyplot as plt

beta = 0.1
n = 3
p = np.arange(10)*0.05
plt.plot(p,n*beta + p*n)
plt.plot(p,n*beta + (1-(1-p)**n))
plt.xlabel('Probability of pair infection')
plt.ylabel('Driver R number')
# Out:
# Text(0, 0.5, 'Driver R number')
