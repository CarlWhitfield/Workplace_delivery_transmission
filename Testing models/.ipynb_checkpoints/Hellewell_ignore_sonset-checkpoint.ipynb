# %% [markdown]
# Reanalyze Helewell data relative to symtpom onset

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import datetime as dt
import pymc3 as pm

# %%
sympt = pd.read_csv('~/Documents/Github/pcr-profile/symptom_data.csv')
test = pd.read_csv('~/Documents/Github/pcr-profile/test_data.csv')
sympt
symponset = 4.8

# %%
ids = np.unique(sympt['num_id'])
sympt['day_no'] = np.zeros(len(sympt),dtype=np.int)
for i in np.arange(len(sympt)):
    dh = dt.datetime.strptime(sympt['date'][i],'%Y-%m-%d')
    td = dh - dt.datetime.strptime('2020-01-01','%Y-%m-%d')
    sympt.loc[i,'day_no'] = td.days

test['day_no'] = np.zeros(len(test),dtype=np.int)
for i in np.arange(len(test)):
    dh = dt.datetime.strptime(test['date'][i],'%Y-%m-%d')
    td = dh - dt.datetime.strptime('2020-01-01','%Y-%m-%d')
    test.loc[i,'day_no'] = td.days
    
first_day = np.min(test['day_no'].to_numpy())

# %%
symptids = np.array([],dtype=np.int)
for i in ids:
    if np.any(sympt['symptom'][sympt['num_id'] == i]):
        symptids = np.append(symptids,i)

sympt_lb = np.zeros(len(symptids),dtype=np.int)
sympt_ub = np.zeros(len(symptids),dtype=np.int)
test_lb = np.zeros(len(symptids),dtype=np.int)
test_ub = np.zeros(len(symptids),dtype=np.int)

test_days = np.zeros(len(symptids),dtype=np.object)
test_results = np.zeros(len(symptids),dtype=np.object)
total_tests = 0
for i in symptids:
    s = sympt['symptom'][sympt['num_id'] == i].to_numpy()
    d = sympt['day_no'][sympt['num_id'] == i].to_numpy()
    n = np.arange(len(s))
    nh = n[s][0]
    sympt_lb[i-1] = d[nh-1]
    sympt_ub[i-1] = d[nh]
    
    dtest = test['day_no'][test['num_id'] == i].to_numpy()
    t = test['pcr_result'][test['num_id'] == i].to_numpy()
    n = np.arange(len(t))
    if np.any(t > 0):
        nh = n[t][0]
        test_lb[i-1] = dtest[nh-1]
        test_ub[i-1] = dtest[nh]
    else:
        test_lb[i-1] = sympt_lb[i-1]
        test_ub[i-1] = sympt_ub[i-1]
    
    #could put extra tests in at start day
    test_days[i-1] = np.append(np.array([first_day-1]),dtest)
    test_results[i-1] = np.append(np.array([False]),t)
    
    #test_days[i-1] = dtest
    #test_results[i-1] = t
    
    total_tests += len(test_days[i-1])

# %% [markdown]
# All symptomatic
#
# For each individual, define test times

# %%
X = np.zeros(total_tests)
Y = np.zeros(total_tests,dtype=np.bool)
Z = np.zeros(total_tests)
jcount = 0
for i in np.arange(len(symptids)):
    X[jcount:(jcount + len(test_days[i]))] = test_days[i]
    Y[jcount:(jcount + len(test_days[i]))] = test_results[i]
    Z[jcount:(jcount + len(test_days[i]))] = 0.5 * (sympt_lb[i] + sympt_ub[i])
    jcount += len(test_days[i])
# Out:
# 2.98795918367347 0.6173469387755103

# %%
import theano
import theano.tensor as tt

test_model = pm.Model()
Nsamples = 1000
with test_model:    
    stimes = tt.zeros(len(symptids))
    itimes  = tt.zeros(len(symptids))
    for i in np.arange(len(symptids)):
        stimes = tt.set_subtensor(stimes[i],\
                                  pm.Uniform('sonset%d'%i, lower=sympt_lb[i], upper=sympt_ub[i]))
        BoundedGamma = pm.Bound(pm.Gamma, lower=(stimes[i] - np.min([sympt_lb[i],test_lb[i]])))
        itimes = tt.set_subtensor(itimes[i],BoundedGamma('inftime%d'%i, mu = symponset, sigma = 2.8))

    # Priors for unknown model parameters
    C = pm.Normal('C', mu = 0, sigma = 3.0)
    beta1 = pm.Normal('beta1', mu = 0, sigma = 1.0)
    beta2 = pm.Normal('beta2', mu = 0, sigma = 1.0) 
    beta3 = pm.Normal('beta3', mu = 0, sigma = 1.0)
    
    s = tt.zeros(total_tests)
    sp = tt.zeros(total_tests)
    xobs = tt.zeros(total_tests)
    jcount = 0
    for i in np.arange(len(symptids)):
        if len(test_days[i]) > 0:
            xobs = tt.set_subtensor(xobs[jcount],stimes[i]-itimes[i])
            s = tt.set_subtensor(s[jcount:(jcount + len(test_days[i]))], stimes[i])
            sp = tt.set_subtensor(sp[jcount:(jcount + len(test_days[i]))], itimes[i])
        if len(test_days[i]) > 1:              
            xobs = tt.set_subtensor(xobs[(jcount+1):(jcount+len(test_days[i]))],\
                                   X[(jcount+1):(jcount+len(test_days[i]))])          
            jcount += len(test_days[i])
    stest = pm.Deterministic('stest',s)
                      
    rate = pm.math.switch(xobs - s - sp*C > 0, beta2, beta3)
    
    muh = 1 / (1 + pm.math.exp(beta1 + rate * (xobs - s - sp*C)))
    Y_obs = pm.Bernoulli("Y_obs", p = muh, observed=Y)
    S_obs = pm.Gamma("S_obs", mu = symponset, sigma = 2.8, observed = itimes)
    
    param_samples = pm.sample(Nsamples, init='adapt_diag', tune=10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta3, beta2, beta1, C, inftime26, sonset26, inftime25, sonset25, inftime24, sonset24, inftime23, sonset23, inftime22, sonset22, inftime21, sonset21, inftime20, sonset20, inftime19, sonset19, inftime18, sonset18, inftime17, sonset17, inftime16, sonset16, inftime15, sonset15, inftime14, sonset14, inftime13, sonset13, inftime12, sonset12, inftime11, sonset11, inftime10, sonset10, inftime9, sonset9, inftime8, sonset8, inftime7, sonset7, inftime6, sonset6, inftime5, sonset5, inftime4, sonset4, inftime3, sonset3, inftime2, sonset2, inftime1, sonset1, inftime0, sonset0]
# Sampling 4 chains, 0 divergences: 100%|██████████| 44000/44000 [10:00<00:00, 73.27draws/s]
# The acceptance probability does not match the target. It is 0.6508388966216035, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.718548245968116, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8835561280104357, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
ndrange = np.arange(-5,20,0.1)
traces = np.zeros((len(ndrange), Nsamples))
for i in np.arange(Nsamples):
    Xh = ndrange - symptime*param_samples['C'][i]
    traces[:,i] =  1 / (1 + np.exp(param_samples['beta1'][i] + param_samples['beta2'][i] * Xh * (Xh>0) + \
                                   param_samples['beta3'][i] * Xh * (Xh<0)))
    
plt.plot(ndrange, np.median(traces,1),c='k')
plt.plot(ndrange, np.quantile(traces,0.975,1),c='r')
plt.plot(ndrange, np.quantile(traces,0.025,1),c='r')
plt.plot([0,0],[0,1],'--',c=[0.5,0.5,0.5])
plt.xlabel('Days from symptom onset')
plt.ylabel('PCR positive probability')
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
plt.hist(param_samples['C'],bins=20)
plt.hist(param_samples['beta1'],bins=20)
plt.hist(param_samples['beta2'],bins=20)
plt.hist(param_samples['beta3'],bins=20)
# Out:
# (array([1.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 9.000e+00,
#         1.400e+01, 3.400e+01, 4.900e+01, 6.100e+01, 9.100e+01, 1.250e+02,
#         1.760e+02, 2.170e+02, 2.740e+02, 3.160e+02, 4.820e+02, 8.330e+02,
#         1.063e+03, 2.450e+02]),
#  array([-3.64998401, -3.46430288, -3.27862174, -3.09294061, -2.90725947,
#         -2.72157834, -2.53589721, -2.35021607, -2.16453494, -1.9788538 ,
#         -1.79317267, -1.60749154, -1.4218104 , -1.23612927, -1.05044813,
#         -0.864767  , -0.67908586, -0.49340473, -0.3077236 , -0.12204246,
#          0.06363867]),
#  <a list of 20 Patch objects>)

# %%
y = np.median(traces,1)
meanpos = np.trapz(y,ndrange)
psfrac = np.trapz(y[ndrange < 0],ndrange[ndrange < 0])/meanpos
meanposday = np.trapz(y*ndrange,ndrange) / meanpos
varposday = np.trapz(y*(ndrange - meanposday)**2,ndrange) / meanpos

# %%
print(psfrac)
# Out:
# 0.45859727065600014

# %%
fitted = pd.read_csv('~/Documents/Github/pcr-profile/PCR_curve_summary.csv')
psint = np.trapz(fitted['median'][fitted['days_since_infection'] < symponset], \
                 fitted['days_since_infection'][fitted['days_since_infection'] < symponset])
asint = np.trapz(fitted['median'][fitted['days_since_infection'] >= symponset], \
                 fitted['days_since_infection'][fitted['days_since_infection'] >= symponset])
a = symponset - psint / 0.8
b = symponset + asint / 0.8
plt.plot(fitted['days_since_infection'],fitted['median'])
plt.plot(ndrange + symponset, np.median(traces,1),c='k')
plt.plot([0,a,a,b,b,30],[0,0,0.8,0.8,0,0])
print(a,b-a)
# Out:
# 2.38822210748218 10.61060599686907

# %%
import seaborn as sns

ids = np.zeros(Nsamples*len(symptids),dtype=np.int)
sotime = np.zeros(Nsamples*len(symptids))
speriod = np.zeros(Nsamples*len(symptids))
for n in np.arange(Nsamples):
    for j in np.arange(len(symptids)):
        ids[n*len(symptids) + j] = symptids[j]
        sotime[n*len(symptids) + j] = param_samples['sonset%d'%j][n]
        speriod[n*len(symptids) + j] = param_samples['inftime%d'%j][n]
        
dicth = {'ids':ids, 'sotime':sotime, 'speriod':speriod}
df = pd.DataFrame(dicth)

# %%
sns.violinplot(x='ids',y='sotime',data=df)
plt.scatter(symptids-1, sympt_lb, c='r')
plt.scatter(symptids-1, sympt_ub, c='r')

# %%
sns.violinplot(x='ids',y='speriod',data=df)

# %%
fitted = pd.read_csv('~/Documents/Github/pcr-profile/LFT_curve_summary.csv')
psint = np.trapz(fitted['median'][fitted['days_since_infection'] < symponset], \
                 fitted['days_since_infection'][fitted['days_since_infection'] < symponset])
asint = np.trapz(fitted['median'][fitted['days_since_infection'] >= symponset], \
                 fitted['days_since_infection'][fitted['days_since_infection'] >= symponset])
a = symponset - psint / 0.65
b = symponset + asint / 0.65
plt.plot(fitted['days_since_infection'],fitted['median'])
plt.plot([0,a,a,b,b,30],[0,0,0.65,0.65,0,0])
print(a,b-a)
# Out:
# 2.7761035939671292 5.455838366083309
